# %%
from matplotlib import pyplot as plt
import pandas as pd
import geopandas as gpd
from shapely import wkt

df = pd.read_csv('./data/populacao_BR_censos_pib_2022_2010.csv', sep = ';')

# %%
gdf = gpd.GeoDataFrame(df)
gdf['geometry'] = gdf['geometry'].apply(wkt.loads)
gdf = gdf.set_geometry('geometry')

# %%
gdf.head()
# Out:
#    COD_IBGE              MUNICIPIO  UF  POPULACAO_2022  POPULACAO_2010  \
# 0   1100015  Alta Floresta D'Oeste  RO           21495           24392
# 1   1100023              Ariquemes  RO           96833           90353
# 2   1100031                 Cabixi  RO            5363            6313
# 3   1100049                 Cacoal  RO           86895           78574
# 4   1100056             Cerejeiras  RO           15890           17029
#
#    AREA_KM2     PIB_2020  PIB_PER_CAPITA_2020  \
# 0  7067.127   570272.326             25091.18
# 1  4426.571  2818048.618             25730.20
# 2  1314.352   167189.811             32226.25
# 3  3793.000  2519352.677             29331.29
# 4  2783.300   600670.074             37069.25
#
#                        ATIV_MAIOR_VL_ADICIONADO_2020  \
# 0  Administração, defesa, educação e saúde públic...
# 1                                    Demais serviços
# 2  Administração, defesa, educação e saúde públic...
# 3                                    Demais serviços
# 4  Comércio e reparação de veículos automotores e...
#
#                ATIV_SEGUNDO_MAIOR_VL_ADICIONADO_2020  \
# 0               Pecuária, inclusive apoio à pecuária
# 1  Administração, defesa, educação e saúde públic...
# 2               Pecuária, inclusive apoio à pecuária
# 3  Administração, defesa, educação e saúde públic...
# 4                                    Demais serviços
#
#               ATIV_TERCEIRO_MAIOR_VL_ADICIONADO_2020  \
# 0                                    Demais serviços
# 1  Comércio e reparação de veículos automotores e...
# 2  Agricultura, inclusive apoio à agricultura e a...
# 3  Comércio e reparação de veículos automotores e...
# 4  Administração, defesa, educação e saúde públic...
#
#                                             geometry
# 0  POLYGON ((-62.00806 -12.13379, -62.00784 -12.2...
# 1  POLYGON ((-63.17933 -10.13924, -63.17746 -10.1...
# 2  POLYGON ((-60.52408 -13.32137, -60.37162 -13.3...
# 3  POLYGON ((-61.35502 -11.50452, -61.35524 -11.5...
# 4  POLYGON ((-60.82135 -13.11910, -60.81773 -13.1...

# %%
gdf.plot()
plt.show()
